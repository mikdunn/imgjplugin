# %% [markdown]
# # Java kernel smoketest
#
# This notebook is configured to run on the **BeakerX Java** kernel installed in this repo’s portable Jupyter environment.

# %%
System.out.println("Hello from the Java Jupyter kernel (BeakerX)!");
int a = 1;
int b = 2;
a + b
